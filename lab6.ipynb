# %%
import numpy as np

X=np.load(r"C:\Users\Srikanth\Downloads\ML\ML-lab6-main\activation_maps_binarization_Bangli-P9.jpg.npy")
y=np.load(r"C:\Users\Srikanth\Downloads\ML\ML-lab6-main\activation_maps_binarization_mask_Bangli-P9.jpg.npy")
print(X.shape,y.shape)
# Out:
# (1284765, 34) (1284765, 1)

# %%
# Reshape your data into a 2D format (pixels x features)
num_samples = X.shape[0]   # Total number of pixels
num_features = X.shape[1]  # Number of features for each pixel
X_reshaped = X.reshape(num_samples, num_features)
y_reshaped = y.reshape(num_samples)  # Assuming y is your pixel-wise label mask
print(X_reshaped.shape,y_reshaped.shape)
# Out:
# (1284765, 34) (1284765,)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 6)) 
plt.scatter(X[:,0], X[:,1])

# Add labels and a title
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Scatter Plot')

# Show the plot
plt.show()

# %%
X[0:5,0]
# Out:
# array([0.57254902, 0.54117647, 0.38431373, 0.36862745, 0.36862745])

# %%
X[0:5,1]
# Out:
# array([0.44705882, 0.43921569, 0.36470588, 0.33333333, 0.33333333])

# %%
np.unique(y)
# Out:
# array([  0, 255], dtype=uint8)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

independent_feature = X[:, 0]
dependent_feature = X[:, 1]

# Create a Linear Regression model
model = LinearRegression()

# Reshape the independent feature to 2D
independent_feature = independent_feature.reshape(-1, 1)

# Fit the model
model.fit(independent_feature, dependent_feature)

# Make predictions
predicted_values = model.predict(independent_feature)

mse = mean_squared_error(dependent_feature, predicted_values)
mse
# Out:
# 0.0035147969312815798

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# Load your data for dataset 'b'
data_b = y

# Assuming 'data_b' contains features, and we will use a single feature for linear regression

# Select the single feature for dataset 'b'
feature_b = data_b[:, 0]

# Create a Linear Regression model for dataset 'b'
model_b = LinearRegression()
feature_b = feature_b.reshape(-1, 1)
model_b.fit(feature_b, feature_b)  # Predicting the same feature

# Make predictions
predicted_values_b = model_b.predict(feature_b)

# Calculate the Mean Squared Error (MSE)
mse_b = mean_squared_error(feature_b, predicted_values_b)

# Plot the original data and the linear regression line for dataset 'b'
plt.figure(figsize=(10, 6))
plt.scatter(feature_b, feature_b, label='Original Data (Dataset B)')
plt.plot(feature_b, predicted_values_b, color='blue', label='Linear Regression Line')
plt.xlabel('Feature (Dataset B)')
plt.ylabel('Predicted Feature')
plt.title('Univariate Linear Regression (Dataset B)')
plt.legend()

# Print the Mean Squared Error for dataset 'b'
print(f'Mean Squared Error (MSE) for Dataset B: {mse_b}')

plt.show()
# Out:
# Mean Squared Error (MSE) for Dataset B: 1.1948442971936881e-20

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

data = X

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(data[:, :-1], data[:, -1], test_size=0.2, random_state=42)

# Create and train a Linear Regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Make predictions using the model
y_pred = model.predict(X_test)

# Calculate Mean Squared Error (MSE) to evaluate the model
mse = mean_squared_error(y_test, y_pred)

print(f"Mean Squared Error (MSE): {mse:.2f}")
# Out:
# Mean Squared Error (MSE): 0.01

# %%
import numpy as np
from sklearn.tree import DecisionTreeRegressor
import matplotlib.pyplot as plt

# Select two features (e.g., feature 0 and feature 1)
feature1 = X[:, 0]
feature2 = X[:, 1]

# Combine the features
a = np.column_stack((feature1, feature2))
b = y  # Target values

# Create a Regression Tree model
tree_regressor = DecisionTreeRegressor(random_state=0)
tree_regressor.fit(a,b)

# Make predictions using the model
tree_regressor.predict(a)
# Out:
# array([255.        , 245.89285714, 232.37475812, ..., 255.        ,
#        255.        , 255.        ])

# %%
import numpy as np
from sklearn.tree import DecisionTreeRegressor
import matplotlib.pyplot as plt

# Create a Regression Tree model
tree_regressor = DecisionTreeRegressor(random_state=0)
tree_regressor.fit(a,b)

# Make predictions using the model
tree_regressor.predict(a)
# Out:
# array([255.        , 245.89285714, 232.37475812, ..., 255.        ,
#        255.        , 255.        ])
